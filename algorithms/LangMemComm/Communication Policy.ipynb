# %% [markdown]
# ### Setup environements and keyboard actor

# %%
import gym
import numpy as np

from src.envs.parsers.predator_prey import PredatorPrey_Parser

class KeyboardMAS():
    possible_actions = "sqzd "
    def __init__(self, n_agents):
        self.n_agents = n_agents

    def _str_actions_valid(self, str_actions):
        if (len(str_actions) != self.n_agents or 
                not all([str_actions[i] in self.possible_actions 
                         for i in range(len(str_actions))])):
            return False
        return True

    def _str_actions_to_numpy(self, str_actions):
        actions = [self.possible_actions.find(str_actions[i]) 
                   for i in range(self.n_agents)]
        return np.array(actions)

    def get_actions(self):
        while True:
            str_actions = input(f"Enter {self.n_agents} actions (valid actions are '{self.possible_actions}'):")
            if self._str_actions_valid(str_actions):
                break
            else:
                print("Invalid actions")
        return self._str_actions_to_numpy(str_actions)
    
class RandomMAS():
    def __init__(self, n_agents):
        self.n_agents = n_agents

    def get_actions(self):
        return np.random.randint(5, size=self.n_agents)
    
gym.envs.register(
    id='PredPrey5x5-v0',
    entry_point='src.envs.ma_gym.envs.predator_prey:PredatorPrey')
gym.envs.register(
    id='PredPrey7x7-v0',
    entry_point='src.envs.ma_gym.envs.predator_prey:PredatorPrey',
    kwargs={'grid_shape': (7, 7),
            'n_agents': 4, 
            'n_preys': 2})

# %% [markdown]
# # Pre-training language modules

# %%
import copy
import torch
import random
from torch import nn

from src.lmc.modules.lm import OneHotEncoder, GRUEncoder, GRUDecoder
from src.lmc.modules.obs import ObservationEncoder
from src.lmc.modules.lang_buffer import LanguageBuffer

"""class LanguageBuffer:

    def __init__(self, max_steps, obs_dim, voc_dim):
        self.max_steps = max_steps
        
        self.obs_buff = np.zeros((max_steps, obs_dim))
        self.sent_buff = np.zeros((max_steps, voc_dim))

        self.filled_i = 0  # index of first empty location in buffer (last index when full)
        self.curr_i = 0  # current index to write to (ovewrite oldest data)

    def __len__(self):
        return self.filled_i

    def store(self, obs, sent):
        nentries = obs.shape[0]  # handle multiple parallel environments
        if self.curr_i + nentries > self.max_steps:
            rollover = self.max_steps - self.curr_i # num of indices to roll over
            self.obs_buff = np.roll(self.obs_buff, rollover, axis=0)
            self.sent_buff = np.roll(self.sent_buff, rollover, axis=0)
            self.curr_i = 0
            self.filled_i = self.max_steps
        
        self.obs_buff[self.curr_i:self.curr_i + nentries] = obs
        self.sent_buff[self.curr_i:self.curr_i + nentries] = sent
        
        self.curr_i += nentries
        if self.filled_i < self.max_steps:
            self.filled_i += nentries
        if self.curr_i == self.max_steps:
            self.curr_i = 0

    def sample(self, N):
        ids = np.random.choice(np.arange(self.filled_i), size=N, replace=False)
        return self.obs_buff[ids], self.sent_buff[ids]"""
"""class LanguageBuffer:

    def __init__(self, max_steps):
        self.max_steps = max_steps

        self.obs_buffer = []
        self.sent_buffer = []

    def store(self, obs_list, sent_list):
        for obs, sent in zip(obs_list, sent_list):
            if len(self.obs_buffer) == self.max_steps:
                self.obs_buffer.pop(0)
                self.sent_buffer.pop(0)
            self.obs_buffer.append(obs)
            self.sent_buffer.append(sent)

    def sample(self, batch_size):
        if batch_size > len(self.obs_buffer):
            batch_size = len(self.obs_buffer)
        ids = np.random.choice(
            np.arange(len(self.obs_buffer)), size=batch_size, replace=False)
        obs_batch = [self.obs_buffer[i] for i in ids]
        sent_batch = [self.sent_buffer[i] for i in ids]
        return obs_batch, sent_batch"""
    

class LanguageLearner:

    def __init__(self, obs_dim, context_dim, hidden_dim, vocab,
                 lang_lr, lang_n_epochs, lang_batch_size, lang_temp, 
                 lang_clip_weight, lang_capt_weight, lang_obs_learn_capt, 
                 lang_buffer_size):
        self.lr = lang_lr
        self.n_epochs = lang_n_epochs
        self.batch_size = lang_batch_size
        self.temp = lang_temp
        self.clip_weight = lang_clip_weight
        self.capt_weight = lang_capt_weight
        self.obs_learn_capt = lang_obs_learn_capt

        self.word_encoder = OneHotEncoder(vocab)

        self.obs_encoder = ObservationEncoder(obs_dim, context_dim, hidden_dim)
        self.lang_encoder = GRUEncoder(context_dim, hidden_dim, self.word_encoder)
        self.decoder = GRUDecoder(context_dim, self.word_encoder)

        self.clip_loss = nn.CrossEntropyLoss()
        self.captioning_loss = nn.NLLLoss()

        self.optim = torch.optim.Adam(
            list(self.obs_encoder.parameters()) + 
            list(self.lang_encoder.parameters()) + 
            list(self.decoder.parameters()), 
            lr=lr)

        self.buffer = LanguageBuffer(lang_buffer_size)
    
    def store(self, obs, sent):
        # enc_sent = self.word_encoder.encode_batch(sent)
        self.buffer.store(obs, sent)

    def encode_sentences(self, sentence_batch):
        """ 
        Encode a batch of sentences. 
        :param sentence_batch (list(list(str))): Batch of sentences.

        :return context_batch (torch.Tensor): Batch of context vectors, 
            dim=(batch_size, context_dim).
        """
        context_batch = self.lang_encoder(sentence_batch).squeeze(0)
        return context_batch
    
    def encode_observations(self, obs_batch):
        context_batch = self.obs_encoder(obs_batch)
        return context_batch

    def generate_sentences(self, context_batch):
        """ 
        Generate sentences from a batch of context vectors. 
        :param context_batch (torch.Tensor): Batch of context vectors,
            dim=(batch_size, context_dim).
        
        :return gen_sent_batch (list(list(str))): Batch of generated sentences.
        """
        _, preds = self.decoder(context_batch)

        gen_sent_batch = self.word_encoder.decode_batch(preds)
        return gen_sent_batch

    def compute_losses(self, obs_batch, sent_batch):
        # Encode observations
        obs_tensor = torch.Tensor(np.array(obs_batch))
        obs_context_batch = self.obs_encoder(obs_tensor)

        # Encode sentences
        lang_context_batch = self.lang_encoder(sent_batch)
        lang_context_batch = lang_context_batch.squeeze()

        # Compute similarity
        norm_context_batch = obs_context_batch / obs_context_batch.norm(
            dim=1, keepdim=True)
        lang_context_batch = lang_context_batch / lang_context_batch.norm(
            dim=1, keepdim=True)
        sim = norm_context_batch @ lang_context_batch.t() * self.temp
        mean_sim = sim.diag().mean()

        # Compute CLIP loss
        labels = torch.arange(len(obs_batch))
        loss_o = self.clip_loss(sim, labels)
        loss_l = self.clip_loss(sim.t(), labels)
        clip_loss = (loss_o + loss_l) / 2
        
        # Decoding
        encoded_targets = self.word_encoder.encode_batch(sent_batch)
        if not self.obs_learn_capt:
            obs_context_batch = obs_context_batch.detach()
        decoder_outputs, _ = self.decoder(obs_context_batch, encoded_targets)

        # Compute Captioning loss
        dec_loss = 0
        for d_o, e_t in zip(decoder_outputs, encoded_targets):
            e_t = torch.argmax(e_t, dim=1)
            dec_loss += self.captioning_loss(d_o, e_t)
        
        return clip_loss, dec_loss, mean_sim

    def train(self):
        clip_losses = []
        dec_losses = []
        mean_sims = []
        for it in range(self.n_epochs):
            self.optim.zero_grad()
            # Sample batch from buffer
            obs_batch, sent_batch = self.buffer.sample(self.batch_size)

            # Compute losses
            clip_loss, dec_loss, mean_sim = self.compute_losses(obs_batch, sent_batch)

            # Update
            tot_loss = self.clip_weight * clip_loss + self.capt_weight * dec_loss
            tot_loss.backward()
            self.optim.step()

            clip_losses.append(clip_loss.item() / batch_size)
            dec_losses.append(dec_loss.item() / batch_size)
            mean_sims.append(mean_sim.item())
        
        
        clip_loss = sum(clip_losses) / len(clip_losses)
        dec_loss = sum(dec_losses) / len(dec_losses)
        mean_sim = sum(mean_sims) / len(mean_sims)
        
        return clip_loss, dec_loss, mean_sim

# %%
from src.log.progress_bar import Progress

def pretrain_language(env, parser, actor, lang_learner, n_steps=10000, print_progress=True):
    if print_progress:
        progress = Progress(n_steps)
    
    clip_losses, capt_losses, mean_sims = [], [], []
    step_i = 0
    obs = env.reset()
    while step_i < n_steps:
        if print_progress:
            progress.print_progress(step_i)
        # Parse obs
        sent = parser.parse_observations(obs)
        #print(sent)
        # Store in buffer
        lang_learner.store(obs, sent)
        # Sample actions
        actions = actor.get_actions()
        # Env step
        obs, rewards, dones, infos = env.step(actions)
        # End of episode
        if all(dones):
            clip_loss, capt_loss, mean_sim = lang_learner.train()
            if np.isnan(clip_loss) or np.isnan(capt_loss) or np.isnan(mean_sim):
                print("nan")
                return 1
            clip_losses.append(clip_loss)
            capt_losses.append(capt_loss)
            mean_sims.append(mean_sim)
            obs = env.reset()
        step_i += 1
    env.close()
    return clip_losses, capt_losses, mean_sims

# %%
import matplotlib.pyplot as plt

def plot_curves(curves, titles):
    """
    Inputs:
        curves (list(list(list(float)))): list of list of training curves, each element i of the main list is a list
            of all the training curves to plot in the subplot i.
    """
    nb_subplots = len(curves)
    
    fig, axs = plt.subplots(1, nb_subplots, figsize=(15,6))
    if type(axs) is not np.ndarray:
        axs = [axs]
    for ax, plot, title in zip(axs, curves, titles):
        max_len = max([len(c) for c in plot])
        for c in plot:
            c_len = len(c)
            if c_len == max_len:
                ax.plot(c)
            else:
                inter = max_len / c_len
                ax.plot((np.arange(c_len) + 1) * inter, c)
        ax.set_title(title)

# %%
# Training parameters
n_steps = 100000
# Language parameters
context_dim = 16
hidden_dim = 32
lr = 0.007
batch_size = 128
clip_weight = 1.0
capt_weight = 1.0
obs_learn_capt = True
buffer_size = 100000

env = gym.make('PredPrey7x7-v0')
parser = PredatorPrey_Parser()
actor = RandomMAS(env.n_agents)

lang_learner = LanguageLearner(
    env.observation_space[0].shape[0], 
    context_dim, 
    hidden_dim, 
    parser.vocab,
    lr, 
    1, 
    batch_size, 
    1.0, 
    clip_weight, 
    capt_weight, 
    obs_learn_capt, 
    buffer_size)

clip_losses, capt_losses, mean_sims = pretrain_language(env, parser, actor, lang_learner, n_steps)

plot_curves([[clip_losses], [mean_sims], [capt_losses]], ["CLIP", "Cosine Sim", "Captioning"])
# Out:
# 100% | 99999/100000 (0:05:10<0:00:00, 321.08step/sec)

# %%
# Training parameters
n_steps = 1000
# Language parameters
context_dim = 16
hidden_dim = 32
lr = 0.007
batch_size = 128
clip_weight = 1.0
capt_weight = 1.0
obs_learn_capt = True
buffer_size = 100000

env = gym.make('PredPrey7x7-v0')
parser = PredatorPrey_Parser()
actor = RandomMAS(env.n_agents)

lang_learner = LanguageLearner(
    env.observation_space[0].shape[0], 
    context_dim, 
    hidden_dim, 
    parser.vocab,
    lr, 
    1, 
    batch_size, 
    1.0, 
    clip_weight, 
    capt_weight, 
    obs_learn_capt, 
    buffer_size)

clip_losses, capt_losses, mean_sims = pretrain_language(env, parser, actor, lang_learner, n_steps)

plot_curves([[clip_losses], [mean_sims], [capt_losses]], ["CLIP", "Cosine Sim", "Captioning"])
# Out:
# 100% | 999/1000 (0:00:03<0:00:00, 227.44step/sec)

# %% [markdown]
# # Learning a communication policy using pretrained language modules

# %%
def test_captioning(env, parser, actor, lang_learner, n_steps=100):
    progress = Progress(n_steps)
    step_i = 0
    obs = env.reset()
    while step_i < n_steps:
        progress.print_progress(step_i)
        # Parse obs
        sent = parser.parse_observations(obs)
        print(sent)
        # Store in buffer
        context = lang_learner.obs_encoder(torch.Tensor(obs))
        capt = lang_learner.generate_sentences(context)
        print(capt)
        # Sample actions
        actions = actor.get_actions()
        # Env step
        obs, rewards, dones, infos = env.step(actions)
        # End of episode
        if all(dones):
            obs = env.reset()
        input()
        step_i += 1
    env.close()

test_captioning(env, parser, actor, lang_learner)

# %% [markdown]
# ### MLP Encoder in Communication Policy

# %%
import copy
import torch
import numpy as np
import torch.nn.functional as F

from torch import nn

from src.lmc.modules.networks import MLPNetwork


def _cast(x):
    if len(x.shape) == 3:
        return x.transpose(1, 0, 2).reshape(-1, *x.shape[2:])
    elif len(x.shape) == 4:
        return x.transpose(1, 0, 2, 3).reshape(-1, *x.shape[2:])
    else:
        return x.transpose(1, 0, 2, 3, 4).reshape(-1, *x.shape[2:])

def _flatten(T, N, x):
    return x.reshape(T * N, *x.shape[2:])

def torch2numpy(x):
    return x.detach().cpu().numpy()
    

class CommBuffer_MLP:
    
    def __init__(self, context_dim, hidden_dim, max_sent_len, token_dim, gamma=0.99, n_mini_batch=2):
        self.context_dim = context_dim
        self.hidden_dim = hidden_dim
        self.max_sent_len = max_sent_len
        self.token_dim = token_dim
        assert gamma <= 1
        self.gamma = gamma
        self.n_mini_batch = n_mini_batch
        
        self.input_context = None
        self.generated_tokens = None
        self.token_log_probs = None
        self.value_preds = None
        self.returns = None
        self.masks = None
        
    """def insert(self, input_context, generated_tokens, token_log_probs, 
               value_preds, rewards, masks, token_masks):
        self.input_context[self.step + 1] = input_context.copy()
        self.encoder_rnn_states[self.step + 1] = encoder_rnn_states.copy()
        self.generated_tokens[self.step + 1] = generated_tokens.copy()
        self.token_log_probs[self.step + 1] = token_log_probs.copy()
        self.value_preds[self.step + 1] = value_preds.copy()
        self.rewards[self.step + 1] = rewards.copy()
        self.masks[self.step + 1] = masks.copy()
        self.token_masks[self.step + 1] = token_masks.copy()
        self.step += 1"""
        
    def reset_episode(self):
        self.input_context = None # np.zeros((self.max_sent_len + 1, self.batch_size, self.context_dim * 2), dtype=np.float32)
        self.generated_tokens = None # np.zeros((self.max_sent_len + 1, self.batch_size, self.token_dim), dtype=np.float32)
        self.token_log_probs = None # np.zeros((self.max_sent_len, self.batch_size, self.token_dim), dtype=np.float32)
        self.value_preds = None # np.zeros((self.max_sent_len + 1, self.batch_size, 1), dtype=np.float32)
        self.returns = None # np.zeros((self.max_sent_len + 1, self.batch_size, 1), dtype=np.float32)
        self.masks = None # np.ones((self.max_sent_len + 1, self.batch_size, 1), dtype=np.float32)
        
    def store_gen(self, input_context, gen_tokens, token_log_probs, value_preds, masks):
        """
        Store a batch of generated sequences.
        """
        self.input_context = input_context
        self.generated_tokens = gen_tokens
        self.token_log_probs = token_log_probs
        self.value_preds = value_preds
        self.masks = masks            
    
    def compute_returns(self, rewards):
        """
        Compute returns at each step of generations from final rewards.
        :param rewards (np.ndarray): Rewards given for each generated sentences, dim=(batch_size, )
        """
        len_sentences = np.sum(self.masks, axis=0, dtype=int)
        # Set final reward to final token of each sentence
        step_rewards = np.zeros_like(self.masks)
        step_rewards[len_sentences - 1, np.arange(rewards.shape[0], dtype=int)] = rewards
        self.returns = step_rewards.copy()
        
        for s_i in reversed(range(self.returns.shape[0] - 1)):
            self.returns[s_i] = self.returns[s_i + 1] * self.gamma + step_rewards[s_i]
        self.returns = self.returns[..., np.newaxis]
        
    def recurrent_generator(self):
        """
        Randomise experiences and yields mini-batches to train.
        """
        # Each element of the batch is a data_chunk (one env step = generated sequence)
        batch_size = self.input_context.shape[0]
        assert batch_size % self.n_mini_batch == 0
        mini_batch_size = batch_size // self.n_mini_batch
        
        # Compute and normalise advantages
        advantages = self.returns[:-1] - self.value_preds[:-1]
        advantages = (advantages - np.mean(advantages)) / (np.std(advantages) + 1e-8)
        
        # Return mini_batches with permutated indexes
        rand_ids = np.random.permutation(batch_size)
        sample_ids = [rand_ids[i * mini_batch_size:(i + 1) * mini_batch_size] for i in range(self.n_mini_batch)]
        for ids in sample_ids:
            yield self.input_context[ids], self.generated_tokens[:, ids], self.token_log_probs[:, ids], \
                  self.value_preds[:, ids], self.returns[:, ids], advantages[:, ids], self.masks[:, ids]
    
# TODO: orthogonal init of weights comme https://github.com/vwxyzjn/ppo-implementation-details/blob/main/ppo_atari_lstm.py#L112
# TODO: init rnn weigths: weights orthogonal, bias constant 0
# TODO: anneal learning rates
# TODO: Add layer norm all over the place
# TODO: Comment params
# TODO: Add gae
# TODO: During training, play with topk and topp sampling, not taking always the best tokens, see how 
#       that affects exploration/drifting

class TextActorCritic(nn.Module):
    
    def __init__(self, word_encoder, pretrained_decoder, context_dim, max_sent_len):
        super(TextActorCritic, self).__init__()
        self.word_encoder = word_encoder
        self.max_sent_len = max_sent_len
        # RNN encoder
        self.gru = copy.deepcopy(pretrained_decoder.gru)
        # Policy and value heads
        self.actor = copy.deepcopy(pretrained_decoder.out)
        self.critic = nn.Linear(context_dim, 1)
            
    def gen_messages(self, context_batch):
        """
        :param context_batch (torch.Tensor): Batch of context vectors,
                dim=(batch_size, context_dim).
        """
        batch_size = context_batch.shape[1]
        # Set initial hidden states and token
        hidden = context_batch
        last_tokens = torch.tensor(
            np.array([[self.word_encoder.SOS_ENC]])).float().repeat(1, batch_size, 1)
        
        batch_tokens = []
        batch_token_log_probs = []
        batch_value_preds = []
        batch_masks = [np.ones(batch_size)]
        last_topi = torch.zeros(batch_size)
        # batch_len_sentences = np.zeros(batch_size)
        sentences = [[] for b_i in range(batch_size)]
        for t_i in range(self.max_sent_len):
            # Encode with RNN
            _, hidden = self.gru(last_tokens, hidden)
            
            # Get token predictions from actor
            log_probs = self.actor(hidden)
            
            # Get values from critic
            value_preds = self.critic(hidden)
            
            # Sample next token
            _, topi = log_probs.topk(1)
            topi = topi.squeeze()
            tokens = self.word_encoder.token_encodings[topi]
            
            # Make token_log_prob
            token_log_probs = log_probs.gather(-1, topi.reshape(1, -1, 1))
            
            # Make mask: 1 if last token is not EOS and last mask is not 0
            masks = (np.where(last_topi == self.word_encoder.EOS_ID, 0.0, 1.0) * \
                     np.where(batch_masks[-1] == 0.0, 0.0, 1.0))
            last_topi = topi
            
            # Stop early if all sentences are finished
            if sum(masks) == 0:
                break
            
            # Add decoded tokens to sentences
            for b_i in range(batch_size):
                if batch_masks[-1][b_i]:
                    sentences[b_i].append(self.word_encoder.index2token(topi[b_i]))
            
            batch_tokens.append(tokens)
            batch_token_log_probs.append(torch2numpy(token_log_probs))
            batch_value_preds.append(torch2numpy(value_preds))
            batch_masks.append(masks)
            
            last_tokens = torch.Tensor(tokens).unsqueeze(0)
            
        # Compute last value
        _, hidden = self.gru(last_tokens, hidden)
        value_preds = self.critic(hidden)
        batch_value_preds.append(torch2numpy(value_preds))
        
        tokens = np.stack(batch_tokens, dtype=np.float32)
        token_log_probs = np.concatenate(batch_token_log_probs)
        value_preds = np.concatenate(batch_value_preds)
        masks = np.stack(batch_masks)
        
        return tokens, token_log_probs, value_preds, masks, sentences
    
    def evaluate_tokens(self, context_batch, token_batch):
        # Add SOS token
        sos_tensor = torch.Tensor([self.word_encoder.SOS_ENC]).repeat(1, context_batch.shape[1], 1)
        input_tokens = torch.cat((sos_tensor, token_batch))
        
        outputs, _ = self.gru(input_tokens, context_batch)
        
        # Get log_probs and entropy
        log_probs = self.actor(outputs)
        token_log_probs = log_probs.gather(-1, token_batch.argmax(-1)[..., np.newaxis])
        entropy = -(log_probs * torch.exp(log_probs)).mean()

        # Get values
        value_preds = self.critic(outputs)

        return token_log_probs, entropy, value_preds
        
        

class CommPPO_MLP:
    """ 
    Communication module with a recurrent context encoder, 
    a policy that generates sentences and a value that estimates
    the quality of the current state (previous hidden state).
    It is trained using PPO, fine-tuning a pretrained policy.
    """
    def __init__(self, n_agents, context_dim, hidden_dim, lang_learner, 
                 lr=0.0005, ep_len=10, max_sent_len=12, n_envs=1, gamma=0.99,
                 n_epochs=16, clip_coef=0.2, entropy_coef=0.01, vloss_coef=0.5, max_grad_norm=10.0):
        self.n_agents = n_agents
        self.context_dim = context_dim
        self.hidden_dim = hidden_dim
        self.n_envs = n_envs
        self.n_epochs = n_epochs
        self.clip_coef = clip_coef
        self.entropy_coef = entropy_coef
        self.max_grad_norm = max_grad_norm
        self.vloss_coef = vloss_coef
        
        self.lang_learner = lang_learner
        
        self.context_encoder = MLPNetwork(2 * context_dim, context_dim, norm_in=False)
        
        self.comm_policy = TextActorCritic(
            lang_learner.word_encoder, 
            lang_learner.decoder, 
            context_dim, 
            max_sent_len)
        
        self.optim = torch.optim.Adam(
            list(self.comm_policy.parameters()) + list(self.context_encoder.parameters()), 
            lr=lr, eps=1e-5)
        
        self.buffer = CommBuffer_MLP(
            context_dim, 
            hidden_dim, 
            max_sent_len, 
            self.lang_learner.word_encoder.enc_dim,
            gamma)
        
        self.last_comm = None
        
    def reset_episode(self):
        self.buffer.reset_episode()
        self.last_comm = None
        
    @torch.no_grad()
    def get_messages(self, obs):
        """
        Perform a communication step: encodes obs and previous messages and
        generates messages for this step.
        :param obs (np.ndarray): agents' observations for all parallel 
            environments, dim=(n_envs, n_agents, obs_dim)
            
        :return comm (list(list(str))): messages generated for each agent,
            for each parallel environment
        :return lang_context (np.ndarray): language context vectors to send
            to policy, dim=(n_envs, n_agents, context_dim)
        """
        # Encode inputs
        obs_context = []
        for a_i in range(self.n_agents):
            obs_context.append(self.lang_learner.encode_observations(torch.Tensor(obs[:, a_i])))
        obs_context = torch.stack(obs_context, dim=1)
        #obs_context = self.lang_learner.encode_observations(torch.Tensor(obs))
        if self.last_comm is not None:
            lang_context = self.lang_learner.encode_sentences(self.last_comm)
        else:
            lang_context = torch.zeros_like(obs_context)
            
        input_context = torch.cat((obs_context, lang_context), dim=-1)
        # Flatten rollout and agent dimensions
        assert (self.n_envs, self.n_agents) == tuple(input_context.shape[:2])
        input_context = input_context.view(self.n_envs * self.n_agents, 2 * self.context_dim)
        
        # Encode contexts
        comm_context = self.context_encoder(input_context).unsqueeze(0)
        
        # Generate messages
        tokens, token_log_probs, value_preds, masks, sentences = self.comm_policy.gen_messages(comm_context)
        
        # Store experiences in buffer
        self.buffer.store_gen(torch2numpy(input_context), tokens, token_log_probs, value_preds, masks)
        
        # Arrange sentences by env
        self.last_comm = [sentences[e_i * self.n_agents:(e_i + 1) * self.n_agents] for e_i in range(self.n_envs)]
        
        return self.last_comm, lang_context #, tokens, log_probs, value_preds, masks
    
    def store_rewards(self, rewards):
        """
        Send rewards for each sentences to the buffer to compute returns.
        :param rewards (np.ndarray): Rewards for each generated sentence, dim=(batch_size, )
        """
        self.buffer.compute_returns(rewards)
        
    def ppo_update(self, batch):
        input_context, generated_tokens, token_log_probs, value_preds, returns, advantages, masks = batch
        
        """# Flatten first two dimensions
        print(input_context.shape)
        print(generated_tokens.shape)
        print(token_log_probs.shape)
        print(value_preds.shape)
        print(returns.shape)
        print(advantages.shape)
        print(masks.shape)
        print(masks)
        generated_tokens
        masks = masks.T.reshape(-1)
        # Get rid of useless transitions (happened after EOS token)
        print(masks + np.roll(masks, 1))
        print(generated_tokens)"""
        
        input_context = torch.from_numpy(input_context)
        generated_tokens = torch.from_numpy(generated_tokens)
        token_log_probs = torch.from_numpy(token_log_probs)
        advantages = torch.from_numpy(advantages)
        returns = torch.from_numpy(returns)
        #print(value_preds.shape)
        
        # Evaluate generated tokens
        comm_context = self.context_encoder(input_context).unsqueeze(0)
        new_token_log_probs, entropy, new_value_preds = \
            self.comm_policy.evaluate_tokens(comm_context, generated_tokens)

        # Policy Loss
        ratio = (new_token_log_probs - token_log_probs).exp()
        pol_loss1 = -advantages * ratio
        pol_loss2 = -advantages * torch.clamp(ratio, 1 - self.clip_coef, 1 + self.clip_coef)
        pol_loss = torch.max(pol_loss1, pol_loss2).mean()
        
        # TODO: Add regularisation with pre-trained policy
        
        # Entropy loss
        entropy_loss = entropy.mean()
        
        # Value loss
        val_loss = ((new_value_preds - returns) ** 2).mean()
        
        # Final loss
        loss = pol_loss - self.entropy_coef * entropy_loss + self.vloss_coef * val_loss
        print(loss)
        
        # Update
        self.optim.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.comm_policy.parameters(), self.max_grad_norm)
        nn.utils.clip_grad_norm_(self.context_encoder.parameters(), self.max_grad_norm)
        self.optim.step()
    
    def train(self):
        for e_i in range(self.n_epochs):
            data_generator = self.buffer.recurrent_generator()
            
            for train_batch in data_generator:
                self.ppo_update(train_batch)
                
        
    
    def save(self, path):
        pass

# %%
N = 2
a = CommPPO_MLP(env.n_agents, context_dim, hidden_dim, lang_learner, n_envs=N)

#obs = np.ones((N, env.n_agents, env.observation_space[0].shape[0]))
#obs[1] -= 1
obs = np.random.random((N, env.n_agents, env.observation_space[0].shape[0]))
sentences, lang_context = a.get_messages(obs)
#print("sentences", sentences)
#print("lang_context", lang_context.shape)

np.set_printoptions(precision=4, suppress=True)
a.store_rewards(np.ones(N * env.n_agents))

a.train()
# Out:
# tensor(0.4397, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.4804, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3540, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.4666, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2378, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.4985, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1052, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.5556, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1596, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.4354, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3469, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1876, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2413, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2412, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0732, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3630, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1035, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.4988, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0244, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3334, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1565, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1684, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3077, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0143, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1607, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1038, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0503, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1898, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2941, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0793, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1670, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0251, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0876, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2600, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3843, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2334, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1827, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3676, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2564, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0454, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1408, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0798, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0024, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1628, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1007, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1814, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2294, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0926, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1251, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0392, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0218, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0481, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0428, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0292, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0232, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1763, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1587, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1018, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0736, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3234, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2847, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3570, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.3083, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1966, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1384, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0787, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0119, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2090, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1345, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1289, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2115, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0155, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0743, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0931, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0030, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0063, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1086, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1237, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2319, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1218, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2355, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1143, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0038, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0167, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1058, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0726, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2000, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0296, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1018, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1471, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2827, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0427, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0970, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1021, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2457, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1750, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0281, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4241, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2733, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0822, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0726, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3078, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1498, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1858, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0241, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1563, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0095, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0173, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1863, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2803, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4529, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1037, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2792, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1502, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0279, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1906, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0092, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1592, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0249, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2497, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0626, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1495, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0401, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0691, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2612, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0401, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1543, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1098, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3072, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0426, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2427, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0417, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2442, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0447, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1601, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3252, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1184, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3006, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0914, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1167, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3282, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2005, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0129, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3046, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0887, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2032, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0150, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0873, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3079, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1826, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2601, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4852, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3361, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1089, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2143, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0151, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2797, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0482, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0752, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1583, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1771, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4123, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3521, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1151, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0784, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3175, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0935, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3335, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3189, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0770, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0112, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2330, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0369, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2078, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0489, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1973, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0759, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1720, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2593, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0097, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4907, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2387, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0800, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1742, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1685, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4233, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4703, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2150, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0160, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2729, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1361, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1228, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2120, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4733, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3448, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0826, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3776, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1139, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1369, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4024, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1672, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0995, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3328, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0649, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1688, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1006, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1982, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0728, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2314, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5035, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0779, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3514, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2427, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0317, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1015, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3774, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2008, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0766, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2765, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0021, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3311, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0515, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2029, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0780, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2283, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3650, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0818, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1576, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1260, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1066, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3911, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2029, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4887, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2585, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0280, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0565, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2317, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0492, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2406, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0736, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2160, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2238, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5136, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0888, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2023, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1252, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4182, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3884, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0943, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3406, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0464, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2437, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0513, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0820, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2144, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1493, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4458, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3418, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0445, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2455, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2889, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0121, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1976, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1040, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1115, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1916, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2674, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0364, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3519, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0474, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0451, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2598, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1204, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4264, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2170, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0900, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0389, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3466, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1438, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4517, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0098, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2991, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0392, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2704, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0979, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2127, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2763, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0349, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5263, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2154, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0848, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3966, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1466, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1658, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2963, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0165, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0348, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3478, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1232, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1906, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0168, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2964, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1909, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1232, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0354, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3505, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0900, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2256, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3509, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0349, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3030, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0135, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2648, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0524, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4105, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0931, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2063, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1118, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0184, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3003, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1017, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2174, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4086, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0892, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0150, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3047, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3289, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0089, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5066, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1861, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3407, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0200, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0408, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3615, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4127, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0914, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0914, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4128, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3018, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0193, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3304, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0083, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0910, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4129, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2306, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0912, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2783, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0439, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5075, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1853, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1252, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1973, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2670, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0557, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0429, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2800, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4608, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1377, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2367, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0865, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1976, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1259, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2199, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5435, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2319, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0917, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2788, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0449, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0076, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3315, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3783, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0542, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3318, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0075, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1229, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2015, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0442, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2803, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1149, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2098, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0309, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3556, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3901, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0651, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0459, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2792, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4344, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1096, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4345, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1094, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4624, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1371, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0031, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3284, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0674, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2579, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2261, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0992, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1759, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1496, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1369, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4626, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1238, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2020, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1281, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1979, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0922, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2338, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2350, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0913, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0465, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2797, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1240, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2021, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0465, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2798, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3332, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0067, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5090, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1822, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0685, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2584, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2799, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0465, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0882, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4149, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0462, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2809, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0723, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3993, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0469, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2801, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0638, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3909, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1080, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4353, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3044, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0231, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1572, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1703, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1998, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1279, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0927, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2349, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0180, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3458, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3300, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0022, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0264, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3542, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3341, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0061, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1777, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1503, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4154, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0874, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4155, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0873, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3459, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0179, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3301, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0020, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1252, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2029, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3542, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0261, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0181, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3100, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3663, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0380, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1780, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1504, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0597, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2688, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4116, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0831, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4358, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1073, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1254, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2032, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1013, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2274, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2121, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1167, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2121, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1167, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0238, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3050, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1052, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2238, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3051, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2276, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1015, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3464, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0173, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3917, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0625, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3465, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0173, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1069, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4362, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2365, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0928, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1069, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4363, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2169, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5463, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2480, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0815, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5464, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2168, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0052, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3348, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0930, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2367, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1058, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2240, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3920, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0622, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0697, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2601, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1066, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4365, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0169, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3468, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1293, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2007, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1262, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2039, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0283, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3584, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4653, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1351, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4653, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1351, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0008, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3311, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2816, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0486, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3554, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0250, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5468, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2165, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2605, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0698, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1805, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5107, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4006, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0701, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2004, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1303, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4656, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1349, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2818, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2162, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5470, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1023, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2285, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0249, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3060, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0699, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4008, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0943, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2367, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2247, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1064, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4658, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1346, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3807, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0495, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0817, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4129, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2374, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0940, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1797, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1517, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2013, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1301, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3808, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0493, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0941, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2375, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0907, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2409, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4660, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1343, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5354, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2037, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2250, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1068, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2155, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5473, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2410, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0909, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0158, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3477, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1270, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2050, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0949, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2371, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0255, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3065, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3811, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0489, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3811, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1069, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2254, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3596, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0272, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1339, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4662, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3932, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0609, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1071, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2253, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3812, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0488, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4014, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0690, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2153, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5477, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0704, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2617, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1804, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1523, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0847, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4175, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1337, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4665, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0271, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3600, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5118, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1789, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1524, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1806, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3122, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0209, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3363, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0031, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5480, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0713, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2620, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1035, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2299, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2835, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0498, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1076, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2257, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2621, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0713, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2377, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0957, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2622, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0714, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3366, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0030, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3072, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0264, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2017, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1320, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2503, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0835, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0627, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2712, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0682, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4022, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0628, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2713, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3127, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0215, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2019, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1323, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0146, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3488, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1316, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2027, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1327, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4671, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0025, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3370, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1040, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2305, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2021, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1325, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0226, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3572, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0261, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3608, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1532, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1814, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1778, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5126, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4673, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1326, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3944, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0598, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0964, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2383, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0216, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3131, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2068, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1283, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0514, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2837, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1200, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2152, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1817, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1535, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2845, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0507, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2845, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2070, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1284, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2719, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0635, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3828, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0472, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0222, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3134, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3829, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0472, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1085, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2272, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2840, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0518, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2012, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5371, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4149, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0790, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3614, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0254, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0253, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3615, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3615, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0254, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0966, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2397, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4392, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1029, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5373, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2010, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1047, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2317, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3832, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0468, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0513, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2851, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1028, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4393, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1314, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4680, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3499, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0132, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1048, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2319, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3581, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0850, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2520, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0825, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4196, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0732, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2639, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2856, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0516, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0129, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3502, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1341, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2033, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0327, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3702, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5496, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.2121, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0647, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2728, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0529, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2847, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0822, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4197, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3837, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0462, dtype=torch.float64, grad_fn=<AddBackward0>)
# ...
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3295, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0321, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0081, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5253, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0321, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3295, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0321, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3295, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0082, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3697, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0081, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0878, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2737, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1468, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1763, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1852, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3722, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0893, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1468, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1065, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2550, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3819, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0204, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0321, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3295, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0204, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3819, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0418, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3198, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0532, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1163, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2453, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3198, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0418, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1107, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1689, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1926, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2453, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1163, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2550, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1065, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2189, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1427, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0082, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3697, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0081, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5493, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1877, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4345, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0730, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3000, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0616, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0893, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0878, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2737, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0041, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3656, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1877, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5493, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2737, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0878, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0532, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4345, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0731, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0370, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3984, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2836, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0778, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5253, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1000, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2615, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4269, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0654, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1852, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1763, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3458, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0157, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0654, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4269, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0081, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2616, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1000, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3722, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0779, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2836, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3656, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0041, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1163, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2453, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1426, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2189, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3819, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0204, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1229, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2387, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2550, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1065, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0369, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3984, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2958, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0657, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2311, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1305, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0418, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3198, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3198, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0418, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2836, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0779, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5253, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0321, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3295, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2311, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1305, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4269, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0653, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1041, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2574, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0893, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2836, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0779, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0893, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0158, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3458, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3534, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0081, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0893, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0158, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3458, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0532, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1469, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1469, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2453, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1163, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0321, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3295, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1107, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2508, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1469, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2738, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0878, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0041, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3656, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0041, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3656, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2311, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1305, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1926, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1689, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0490, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5614, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1999, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4269, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0653, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2213, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1402, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0653, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4269, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2147, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1469, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4803, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1188, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5614, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1999, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5614, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1999, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.0779, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2836, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2453, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1163, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.2376, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1239, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1689, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1926, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1852, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.1763, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5253, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.4803, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1188, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1999, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5614, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.0106, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.3722, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(-0.5493, dtype=torch.float64, grad_fn=<AddBackward0>)
# tensor(0.1877, dtype=torch.float64, grad_fn=<AddBackward0>)

# %% [markdown]
# ## RNN Encoder in Communication Policy

# %%
import copy
import torch
import numpy as np
import torch.nn.functional as F

from torch import nn

from src.lmc.modules.networks import MLPNetwork


def _cast(x):
    if len(x.shape) == 3:
        return x.transpose(1, 0, 2).reshape(-1, *x.shape[2:])
    elif len(x.shape) == 4:
        return x.transpose(1, 0, 2, 3).reshape(-1, *x.shape[2:])
    else:
        return x.transpose(1, 0, 2, 3, 4).reshape(-1, *x.shape[2:])

def _flatten(T, N, x):
    return x.reshape(T * N, *x.shape[2:])

def torch2numpy(x):
    return x.detach().cpu().numpy()
    

class CommBuffer:
    
    def __init__(self, episode_len, context_dim, hidden_dim, max_sent_len, token_dim, n_envs=1):
        self.ep_len = episode_len
        self.context_dim = context_dim
        self.hidden_dim = hidden_dim
        self.max_sent_len = max_sent_len
        self.token_dim = token_dim
        self.n_envs = n_envs
        
        self.input_context = np.zeros(
            (episode_len + 1, n_envs, context_dim * 2),
            dtype=np.float32)
        
        self.encoder_rnn_states = np.zeros(
            (episode_len + 1, n_envs, hidden_dim),
            dtype=np.float32)
        
        self.generated_tokens = np.zeros(
            (episode_len, n_envs, max_sent_len, token_dim),
            dtype=np.float32)
        self.token_log_probs = np.zeros(
            (episode_len, n_envs, max_sent_len, token_dim),
            dtype=np.float32)
        
        self.value_preds = np.zeros(
            (episode_len + 1, n_envs, max_sent_len, 1),
            dtype=np.float32)
        self.returns = np.zeros(
            (episode_len + 1, n_envs, max_sent_len, 1),
            dtype=np.float32)
        
        self.rewards = np.zeros(
            (episode_len, n_envs, 1),
            dtype=np.float32)
        
        self.masks = np.ones(
            (episode_len + 1, n_envs, 1),
            dtype=np.float32)
        self.token_masks = np.ones(
            (episode_len + 1, n_envs, max_sent_len, 1),
            dtype=np.float32)
        
        self.step = 0
        
    def insert(self, input_context, encoder_rnn_states, generated_tokens, 
               token_log_probs, value_preds, rewards, masks, token_masks):
        self.input_context[self.step + 1] = input_context.copy()
        self.encoder_rnn_states[self.step + 1] = encoder_rnn_states.copy()
        self.generated_tokens[self.step + 1] = generated_tokens.copy()
        self.token_log_probs[self.step + 1] = token_log_probs.copy()
        self.value_preds[self.step + 1] = value_preds.copy()
        self.rewards[self.step + 1] = rewards.copy()
        self.masks[self.step + 1] = masks.copy()
        self.token_masks[self.step + 1] = token_masks.copy()
        self.step += 1
        
    def reset_episode(self):
        self.input_context = np.zeros((self.ep_len + 1, self.n_envs, self.context_dim * 2),dtype=np.float32)
        self.encoder_rnn_states = np.zeros((self.ep_len + 1, self.n_envs, self.hidden_dim),dtype=np.float32)
        self.generated_tokens = np.zeros((self.ep_len, self.n_envs, self.max_sent_len, self.token_dim),dtype=np.float32)
        self.token_log_probs = np.zeros((self.ep_len, self.n_envs, self.max_sent_len, self.token_dim),dtype=np.float32)
        self.value_preds = np.zeros((self.ep_len + 1, self.n_envs, 1),dtype=np.float32)
        self.returns = np.zeros((self.ep_len + 1, self.n_envs, 1),dtype=np.float32)
        self.rewards = np.zeros((self.ep_len, self.n_envs, self.max_sent_len, self.token_dim),dtype=np.float32)
        self.masks = np.ones((self.ep_len + 1, self.n_envs, 1),dtype=np.float32)
        self.token_mask = np.ones((self.ep_len + 1, self.n_envs, self.max_sent_len, 1),dtype=np.float32)
        self.step = 0
    
    def recurrent_generator(self, advantages, num_mini_batch):
        # Each element of the batch is a data_chunk (one env step = generated sequence)
        batch_size = self.n_envs * self.ep_len
        # data_chunks = batch_size // data_chunk_length
        mini_batch_size = batch_size // num_mini_batch
        
        rand = torch.randperm(batch_size).numpy()
        sampler = [rand[i * mini_batch_size:(i + 1) * mini_batch_size] for i in range(num_mini_batch)]

        input_context = _cast(self.input_context[:-1])
        encoder_rnn_states = _cast(self.encoder_rnn_states[:-1])
        generated_tokens = _cast(self.generated_tokens)
        token_log_probs = _cast(self.token_log_probs)
        value_preds = _cast(self.value_preds[:-1])
        returns = _cast(self.returns[:-1])
        masks = _cast(self.masks[:-1])
        token_masks = _cast(self.token_masks[:-1])
        
        for ids in sampler:
            input_context_batch = input_context[ids]
            generated_tokens_batch = generated_tokens[ids]
            value_preds_batch = value_preds[ids]
            returns_batch = returns[ids]
            masks_batch = masks[ids]
            token_log_probs_batch = token_log_probs[ids]
            adv_targ = advantages[ids]
            encoder_rnn_states_batch = encoder_rnn_states[ids]
            
            yield input_context_batch, encoder_rnn_states_batch, \
                  generated_tokens_batch, value_preds_batch, returns_batch, masks_batch, token_log_probs_batch, \
                  adv_targ
    
# TODO: orthogonal init of weights comme https://github.com/vwxyzjn/ppo-implementation-details/blob/main/ppo_atari_lstm.py#L112
# TODO: init rnn weigths: weights orthogonal, bias constant 0
# TODO: anneal learning rates
# Add layer norm all over the place

class RNNContextEncoder(nn.Module):
    
    def __init__(self, input_dim, hidden_dim):
        super(ContextEncoder, self).__init__()
        self.input = nn.Linear(input_dim, hidden_dim)
        self.gru = nn.GRU(hidden_dim, hidden_dim)
        
    def forward(self, x, rnn_state):
        x = F.relu(self.input(x))
        
        x = x.unsqueeze(0)
        
        x, new_rnn_state = self.gru(x, rnn_state)
        
        return x, new_rnn_state

class TextActorCritic(nn.Module):
    
    def __init__(self, word_encoder, pretrained_decoder, context_dim, max_sent_len):
        super(TextActorCritic, self).__init__()
        self.word_encoder = word_encoder
        self.max_sent_len = max_sent_len
        # RNN encoder
        self.gru = copy.deepcopy(pretrained_decoder.gru)
        # Policy and value heads
        self.actor = copy.deepcopy(pretrained_decoder.out)
        self.critic = nn.Linear(context_dim, 1)
        
    def get_value(self):
        pass
    
    def get_action_and_value(self, context):
        pass
            
    def gen_messages(self, context_batch):
        """
        :param context_batch (torch.Tensor): Batch of context vectors,
                dim=(batch_size, context_dim).
        """
        batch_size = context_batch.shape[1]
        # Set initial hidden states and token
        hidden = context_batch
        last_tokens = torch.tensor(
            np.array([[self.word_encoder.SOS_ENC]])).float().repeat(batch_size, 1, 1)
        
        batch_tokens = [last_tokens.squeeze()]
        batch_log_probs = []
        batch_value_preds = []
        batch_masks = [torch.ones(batch_size)]
        sentences = [[] for b_i in range(batch_size)]
        for t_i in range(self.max_sent_len):
            # Encode with RNN
            _, hidden = self.gru(last_tokens, hidden)
            # Get token predictions from actor
            log_probs = self.actor(hidden)
            # Get values from critic
            value_preds = self.critic(hidden)
            # Sample next token
            _, topi = log_probs.topk(1)
            topi = topi.squeeze()
            tokens = self.word_encoder.token_encodings[topi]
            last_tokens = torch.Tensor(tokens).unsqueeze(1)
            # Make mask
            masks = torch.where(topi == self.word_encoder.EOS_ID, 0.0, 1.0) * \
                    np.where(batch_masks[-1] == 0.0, 0.0, 1.0)
            # Add decoded tokens to sentences
            for b_i in range(batch_size):
                if batch_masks[-1][b_i]:
                    sentences[b_i].append(self.word_encoder.index2token(topi[b_i]))
            # Store
            batch_tokens.append(tokens)
            batch_log_probs.append(torch2numpy(log_probs))
            batch_value_preds.append(torch2numpy(value_preds))
            batch_masks.append(torch2numpy(masks))
            
        # Compute last value
        _, hidden = self.gru(last_tokens, hidden)
        value_preds = self.critic(hidden)
        batch_value_preds.append(torch2numpy(value_preds))
        
        tokens = np.stack(batch_tokens)
        log_probs = np.concatenate(batch_log_probs)
        value_preds = np.concatenate(batch_value_preds)
        masks = np.stack(batch_masks)
        
        return tokens, log_probs, value_preds, masks, sentences
        

class CommPPO_RNN:
    """ 
    Communication module with a recurrent context encoder, 
    a policy that generates sentences and a value that estimates
    the quality of the current state (previous hidden state).
    It is trained using PPO, fine-tuning a pretrained policy.
    """
    def __init__(self, n_agents, context_dim, hidden_dim, lang_learner, 
                 lr=0.0005, ep_len=10, max_sent_len=12, n_envs=1):
        self.n_agents = n_agents
        self.context_dim = context_dim
        self.hidden_dim = hidden_dim
        self.n_envs = n_envs
        
        self.lang_learner = lang_learner
        
        self.context_encoder = ContextEncoder(2 * context_dim, context_dim)
        
        self.comm_policy = TextActorCritic(
            lang_learner.word_encoder, 
            lang_learner.decoder, 
            context_dim, 
            max_sent_len)
        
        self.optim = torch.optim.Adam(
            list(self.comm_policy.parameters()) + list(self.context_encoder.parameters()), 
            lr=lr, eps=1e-5)
        
        self.buffer = CommBuffer(
            ep_len, context_dim, hidden_dim, max_sent_len, 
            self.lang_learner.word_encoder.enc_dim, n_envs)
        
        self.last_comm = None
        self.comm_context = None
        
    def reset_episode(self):
        self.buffer.reset_episode()
        self.last_comm = None
        self.comm_context = None
        
    @torch.no_grad()
    def get_messages(self, obs):
        # Encode inputs
        obs_context = []
        for a_i in range(self.n_agents):
            obs_context.append(self.lang_learner.encode_observations(torch.Tensor(obs[:, a_i])))
        obs_context = torch.stack(obs_context, dim=1)
        #obs_context = self.lang_learner.encode_observations(torch.Tensor(obs))
        if self.last_comm is not None:
            lang_context = self.lang_learner.encode_sentences(self.last_comm)
        else:
            lang_context = torch.zeros_like(obs_context)
            
        full_context = torch.cat((obs_context, lang_context), dim=-1)
        # Flatten rollout and agent dimensions
        assert (self.n_envs, self.n_agents) == tuple(full_context.shape[:2])
        full_context = full_context.view(self.n_envs * self.n_agents, 2 * self.context_dim)
        
        # Encode contexts
        _, self.comm_context = self.context_encoder(full_context, self.comm_context)
        
        # Generate messages
        tokens, log_probs, value_preds, masks, sentences = self.comm_policy.gen_messages(self.comm_context)
        print("tokens", tokens.shape)
        print("log_probs", log_probs.shape)
        print("value_preds", value_preds.shape)
        print("masks", masks.shape)
        print("sentences", sentences)
        
        # Arrange sentences by env
        sentences = [sentences[e_i * self.n_agents:(e_i + 1) * self.n_agents] for e_i in range(self.n_envs)]
        
        return sentences, lang_context, tokens, log_probs, value_preds, masks
    
    def store(self, data):
        pass
    
    def _get_values(self, last_token, rnn_states, masks):
        values, _ = self.critic(last_token, rnn_states)
    
    @torch.no_grad()
    def compute_last_value(self):
        next_value = self._get_values()
    
    def train(self):
        pass
    
    def save(self, path):
        pass

# %%
N = 2
a = CommPPO_RNN(env.n_agents, context_dim, hidden_dim, lang_learner, n_envs=N)

obs = np.ones((N, env.n_agents, env.observation_space[0].shape[0]))
obs[1] -= 1
a.get_messages(obs)
# Out:
# tokens (13, 8, 10)
# log_probs (12, 8, 10)
# value_preds (13, 8, 1)
# masks (13, 8)
# sentences [['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>']]
#
# [['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', 'West', '<EOS>']]
#
# [['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>'], ['Located', 'West', 'Prey', 'Observed', 'South', '<EOS>']]

# %%
t = TextActorCritic(lang_learner.word_encoder, lang_learner.decoder, context_dim, 12)
batch_size = 5
tokens, log_probs, value_preds, masks, sentences = t.get_messages(np.random.random((batch_size, context_dim)))
print("tokens", tokens.shape)
print("log_probs", log_probs.shape)
print("value_preds", value_preds.shape)
print("masks", masks.shape)
print("sentences", sentences)
# Out:
# tokens (13, 5, 10)
# log_probs (12, 5, 10)
# value_preds (13, 5, 1)
# masks (13, 5)
# sentences [['Prey', 'Observed', 'South', '<EOS>'], ['Prey', 'Observed', 'South', '<EOS>'], ['<EOS>'], ['<EOS>'], ['West', 'Prey', 'Observed', 'South', '<EOS>']]
