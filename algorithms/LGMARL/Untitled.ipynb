# %%
from src.utils.decay import ParameterDecay
import matplotlib.pyplot as plt

comm_eps = ParameterDecay(1.0, 0.01, 10000, "exp", 2)

e = [
    comm_eps.get_explo_rate(i)
    for i in range(10000)]

plt.plot(e)

# %%
import numpy as np
fig = plt.figure()
ax = fig.gca()

for s in [0.5, 0.8, 1, 1.2, 1.5, 1.72]:
    comm_eps = ParameterDecay(1.0, 0.01, 100, "sigmoid", s)

    e = [
        comm_eps.get_explo_rate(i)
        for i in range(0,101)]

    plt.plot(e, label=str(s))
    
plt.legend()
plt.grid()
ax.set_yticks(np.arange(0, 1.1, 0.1))
ax.set_xticks(np.arange(0, 101, 5))
# Out:
# [<matplotlib.axis.XTick at 0x7faaf84a27f0>,
#  <matplotlib.axis.XTick at 0x7faaf84a27c0>,
#  <matplotlib.axis.XTick at 0x7faaf84a22b0>,
#  <matplotlib.axis.XTick at 0x7faaf86313d0>,
#  <matplotlib.axis.XTick at 0x7faaf863d850>,
#  <matplotlib.axis.XTick at 0x7faaf83d8340>,
#  <matplotlib.axis.XTick at 0x7faaf83d8df0>,
#  <matplotlib.axis.XTick at 0x7faaf83dd8e0>,
#  <matplotlib.axis.XTick at 0x7faaf863da00>,
#  <matplotlib.axis.XTick at 0x7faaf83ddfa0>,
#  <matplotlib.axis.XTick at 0x7faaf83e3cd0>,
#  <matplotlib.axis.XTick at 0x7faaf83e87c0>,
#  <matplotlib.axis.XTick at 0x7faaf83ef2b0>,
#  <matplotlib.axis.XTick at 0x7faaf83e80d0>,
#  <matplotlib.axis.XTick at 0x7faaf83efbb0>,
#  <matplotlib.axis.XTick at 0x7faaf83f76a0>,
#  <matplotlib.axis.XTick at 0x7faaf83f7f10>,
#  <matplotlib.axis.XTick at 0x7faaf83fcc40>,
#  <matplotlib.axis.XTick at 0x7faaf83fcd30>,
#  <matplotlib.axis.XTick at 0x7faaf86378e0>,
#  <matplotlib.axis.XTick at 0x7faaf85d15e0>]

# %%
for s in [0.5, 0.8, 1, 2, 3, 5, 8, 10, 15, 20]:
    comm_eps = ParameterDecay(1.0, 0.0, 100, "exp", s)

    e = [
        comm_eps.get_explo_rate(i)
        for i in range(100)]

    plt.plot(e, label=str(s))
plt.legend()
