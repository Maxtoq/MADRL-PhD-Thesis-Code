# %%
import pandas as pd


lang = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_lang_ce0/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
noc = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_noc/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
ec = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
ae = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2_ae/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
lg = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec4_lg/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
ae
# Out:
#               Mean return        Std  Median return  Success rate  Success std
# Team compo
# [0, 0, 0, 0]     5.444680  27.787066           15.0      0.939960     0.237561
# [0, 0, 0, 1]     2.022240  28.511677           11.0      0.916680     0.276365
# [0, 0, 1, 1]     0.219292  29.124225          -20.0      0.899167     0.301108
# [0, 0, 1, 2]    -0.154958  29.169927          -20.0      0.898167     0.302429
# [0, 1, 2, 3]    -2.051542  29.438669          -20.0      0.882042     0.322559

# %%
import matplotlib.pyplot as plt

plt.plot(noc["Success rate"], linestyle="--", marker="o")
plt.plot(ec["Success rate"], linestyle="--", marker="o")
plt.plot(ae["Success rate"], linestyle="--", marker="o")
plt.plot(lg["Success rate"], linestyle="--", marker="o")
plt.plot(lang["Success rate"], linestyle="--", marker="o")

plt.ylim(0.85, 1.0)
plt.xticks(list(lang.index), ["AAAA", "AAAB", "AABB", "AABC", "ABCD"])
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=3)

# %%
import matplotlib.pyplot as plt
import pandas as pd

lang = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_lang_ce0/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
noc = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_noc/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
ec = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
ae = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2_ae/zst_log.csv", index_col=0, usecols=list(range(1, 7)))
lg = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec4_lg/zst_log.csv", index_col=0, usecols=list(range(1, 7)))

plt.plot(noc["Success rate"], linestyle="--", marker="o")
plt.plot(ec["Success rate"], linestyle="--", marker="o")
plt.plot(ae["Success rate"], linestyle="--", marker="o")
plt.plot(lg["Success rate"], linestyle="--", marker="o")
plt.plot(lang["Success rate"], linestyle="--", marker="o")

plt.ylim(0.41, 0.77)
fs=16

plt.ylabel("Success rate", fontsize=fs)
plt.xticks(list(lang.index), ["AAAA", "AAAB", "AABB", "AABC", "ABCD"], fontsize=fs)
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=3, fontsize=10)
plt.savefig("/home/maxtoq/Desktop/LAMARL_ICML/ZST.svg", bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

lang = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_lang_ce0/zst_log_hard.csv", index_col=0, usecols=list(range(1, 7)))
noc = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_noc/zst_log_hard.csv", index_col=0, usecols=list(range(1, 7)))
ec = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2/zst_log_hard.csv", index_col=0, usecols=list(range(1, 7)))
ae = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2_ae/zst_log_hard.csv", index_col=0, usecols=list(range(1, 7)))
lg = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec4_lg/zst_log_hard.csv", index_col=0, usecols=list(range(1, 7)))

plt.plot(noc["Success rate"], linestyle="--", marker="o")
plt.plot(ec["Success rate"], linestyle="--", marker="o")
plt.plot(ae["Success rate"], linestyle="--", marker="o")
plt.plot(lg["Success rate"], linestyle="--", marker="o")
plt.plot(lang["Success rate"], linestyle="--", marker="o")

plt.ylim(0.27, 0.67)
plt.xticks(list(lang.index), ["AAAA", "AAAB", "AABB", "AABC", "ABCD"])
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=3)
plt.title("Hard")
plt.show()

# %%
lang
# Out:
#               Mean return        Std  Median return  Success rate  Success std
# Team compo
# [0, 0, 0, 0]    16.421720  25.783685           25.0      0.731640     0.443106
# [0, 0, 0, 1]    14.160440  26.913495           24.0      0.693520     0.461031
# [0, 0, 1, 1]    13.376125  27.154238           23.0      0.679792     0.466556
# [0, 0, 1, 2]    13.784292  27.613483           24.0      0.680792     0.466170
# [0, 1, 2, 3]    13.020292  27.734803           23.0      0.671625     0.469622

# %%
ae
# Out:
#               Mean return        Std  Median return  Success rate  Success std
# Team compo
# [0, 0, 0, 0]     2.752480  28.447267           11.0      0.521320     0.499545
# [0, 0, 0, 1]     0.001800  28.962252          -20.0      0.481040     0.499640
# [0, 0, 1, 1]    -0.936417  29.115302          -20.0      0.469250     0.499054
# [0, 0, 1, 2]    -0.844417  29.174674          -20.0      0.465292     0.498794
# [0, 1, 2, 3]    -2.053917  29.437817          -20.0      0.448292     0.497319

# %%
plt.errorbar(lang.index, noc["Mean return"], yerr=noc["Std"], linestyle="--", marker="o")
plt.errorbar(lang.index, ec["Mean return"], yerr=ec["Std"], linestyle="--", marker="o")
plt.errorbar(lang.index, ae["Mean return"], yerr=ae["Std"], linestyle="--", marker="o")
plt.errorbar(lang.index, lg["Mean return"], yerr=lg["Std"], linestyle="--", marker="o")
plt.errorbar(lang.index, lang["Mean return"], yerr=lang["Std"], linestyle="--", marker="o")

# plt.ylim(0.85, 1.0)
plt.xticks(list(lang.index), ["AAAA", "AAAB", "AABB", "AABC", "ABCD"])
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=3)

# %%
plt.plot(lang.index, noc["Mean return"], linestyle="--", marker="o")
plt.plot(lang.index, ec["Mean return"], linestyle="--", marker="o")
plt.plot(lang.index, ae["Mean return"], linestyle="--", marker="o")
plt.plot(lang.index, lg["Mean return"], linestyle="--", marker="o")
plt.plot(lang.index, lang["Mean return"], linestyle="--", marker="o")

# plt.ylim(0.85, 1.0)
plt.xticks(list(lang.index), ["AAAA", "AAAB", "AABB", "AABC", "ABCD"])
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=3)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

lang = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_lang_ce0/zst_log_E.csv", index_col=0, usecols=list(range(1, 7)))
# noc = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_noc/zst_log_E.csv", index_col=0, usecols=list(range(1, 7)))
ec = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2/zst_log_E.csv", index_col=0, usecols=list(range(1, 7)))
ae = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec2_ae/zst_log_E.csv", index_col=0, usecols=list(range(1, 7)))
lg = pd.read_csv("../../models/magym_PredPrey_RGB/18s50np_ec4_lg/zst_log_E.csv", index_col=0, usecols=list(range(1, 7)))

plt.figure(figsize=(5, 3))
# plt.plot(noc["Mean return"], linestyle="--", marker="o")
plt.errorbar(lang.index, ec["Mean return"], linestyle="--", marker="o", yerr=ec["Std return"])
plt.errorbar(lang.index, ae["Mean return"], linestyle="--", marker="o", yerr=ae["Std return"])
plt.errorbar(lang.index, lg["Mean return"], linestyle="--", marker="o", yerr=lg["Std return"])
plt.errorbar(lang.index, lang["Mean return"], linestyle="--", marker="o", yerr=lang["Std return"])
fs = 10
# plt.ylim(0.41, 0.74)
plt.ylabel("Success rate", fontsize=fs)
plt.xticks(list(lang.index), ["AAAA", "AAAB", "AABB", "AABC", "ABCD"], fontsize=fs)

# Move the legend to the right
plt.legend(["EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=1, fontsize=fs, loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout to provide space for the legend
plt.subplots_adjust(right=0.8)

# plt.savefig("/home/maxtoq/Desktop/LAMARL_ICML/ZST.svg", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Magym CoordPlace

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

lang = pd.read_csv("../../models/magym_CoordPlace_RGB/2a_lang/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
noc = pd.read_csv("../../models/magym_CoordPlace_RGB/2a_noc/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
ec = pd.read_csv("../../models/magym_CoordPlace_RGB/2a_ec2/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
ae = pd.read_csv("../../models/magym_CoordPlace_RGB/2a_ec2_ae/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
lg = pd.read_csv("../../models/magym_CoordPlace_RGB/2a_ec4_lg/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))

plt.figure(figsize=(5, 3))
plt.errorbar(lang.index, noc["Mean return"], linestyle="--", marker="o", yerr=noc["Std return"])
plt.errorbar(lang.index, ec["Mean return"], linestyle="--", marker="o", yerr=ec["Std return"])
plt.errorbar(lang.index, ae["Mean return"], linestyle="--", marker="o", yerr=ae["Std return"])
plt.errorbar(lang.index, lg["Mean return"], linestyle="--", marker="o", yerr=lg["Std return"])
plt.errorbar(lang.index, lang["Mean return"], linestyle="--", marker="o", yerr=lang["Std return"])
fs = 10
# plt.ylim(0.41, 0.74)
plt.ylabel("Mean return", fontsize=fs)
plt.xticks(list(lang.index), ["AA", "AB"], fontsize=fs)

# Move the legend to the right
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=1, fontsize=fs, loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout to provide space for the legend
plt.subplots_adjust(right=0.8)

# plt.savefig("/home/maxtoq/Desktop/LAMARL_ICML/ZST.svg", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## MPE PredPrey

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

lang = pd.read_csv("../../models/mpe_PredPrey_shape/lang_cont/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
noc = pd.read_csv("../../models/mpe_PredPrey_shape/noc_cont/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
ec = pd.read_csv("../../models/mpe_PredPrey_shape/ec2_cont/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
ae = pd.read_csv("../../models/mpe_PredPrey_shape/ec2_AE_cont/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
lg = pd.read_csv("../../models/mpe_PredPrey_shape/ec4_LG_cont/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))

plt.figure(figsize=(2, 3))
plt.errorbar(lang.index, noc["Mean return"], linestyle="--", marker="o", yerr=noc["Std return"])
plt.errorbar(lang.index, ec["Mean return"], linestyle="--", marker="o", yerr=ec["Std return"])
plt.errorbar(lang.index, ae["Mean return"], linestyle="--", marker="o", yerr=ae["Std return"])
plt.errorbar(lang.index, lg["Mean return"], linestyle="--", marker="o", yerr=lg["Std return"])
plt.errorbar(lang.index, lang["Mean return"], linestyle="--", marker="o", yerr=lang["Std return"])
fs = 10
# plt.ylim(0.41, 0.74)
plt.ylabel("Mean return", fontsize=fs)
plt.xticks(list(lang.index), ["AA", "AB"], fontsize=fs)

# Move the legend to the right
plt.legend(["No comm", "EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=1, fontsize=fs, loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout to provide space for the legend
plt.subplots_adjust(right=0.8)

# plt.savefig("/home/maxtoq/Desktop/LAMARL_ICML/ZST.svg", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## MPE Simple ref

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

lang = pd.read_csv("../../models/mpe_simple_color_reference/lang_smolbatch/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
# noc = pd.read_csv("../../models/mpe_simple_color_reference/noc/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
ec = pd.read_csv("../../models/mpe_simple_color_reference/ec2/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
ae = pd.read_csv("../../models/mpe_simple_color_reference/ec2_AE/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))
lg = pd.read_csv("../../models/mpe_simple_color_reference/ec4_LG/zst_log_E.csv", index_col=0, usecols=list(range(1, 12)))

plt.figure(figsize=(2, 3))
# plt.errorbar(lang.index, noc["Mean return"], linestyle="--", marker="o", yerr=noc["Std return"])
plt.errorbar(lang.index, ec["Mean return"], linestyle="--", marker="o", yerr=ec["Std return"])
plt.errorbar(lang.index, ae["Mean return"], linestyle="--", marker="o", yerr=ae["Std return"])
plt.errorbar(lang.index, lg["Mean return"], linestyle="--", marker="o", yerr=lg["Std return"])
plt.errorbar(lang.index, lang["Mean return"], linestyle="--", marker="o", yerr=lang["Std return"])
fs = 10
# plt.ylim(0.41, 0.74)
plt.ylabel("Mean return", fontsize=fs)
plt.xticks(list(lang.index), ["AA", "AB"], fontsize=fs)

# Move the legend to the right
plt.legend(["EC", "EC-AutoEncoder", "EC-LangGround", "LAMARL"], ncols=1, fontsize=fs, loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout to provide space for the legend
plt.subplots_adjust(right=0.8)

# plt.savefig("/home/maxtoq/Desktop/LAMARL_ICML/ZST.svg", bbox_inches="tight")
plt.show()
